# %%
# %pip install pandas sqlalchemy psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:mypassword@localhost:5432/Banking_project"
)

# %%
dim_customers = pd.read_csv("Downloads/clean_customers.csv")
fact_transactions = pd.read_csv("Downloads/clean_transactions.csv")
dim_accounts = pd.read_csv("Downloads/clean_accounts.csv")
fact_loans = pd.read_csv("Downloads/clean_loans.csv")

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    486 non-null    float64
#  1   first_name     486 non-null    object
#  2   last_name      486 non-null    object
#  3   gender         486 non-null    object
#  4   date_of_birth  486 non-null    object
#  5   email          486 non-null    object
#  6   phone_number   486 non-null    object
#  7   city           486 non-null    object
#  8   occupation     486 non-null    object
#  9   join_date      486 non-null    object
#  10  age            486 non-null    int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 41.9+ KB

# %%
engine.connect()

# %%
dim_customers.to_sql(
    "dim_customers",
    engine,
    if_exists="replace",
    index=False
)
print ("Customers table loaded successfuly")
# Out:
# Customers table loaded successfuly

# %%
fact_transactions.to_sql(
    "fact_transactions",
    engine,
    if_exists="replace",
    index=False
)
print("Transactions table loaded successfuly")
# Out:
# Transactions table loaded successfuly

# %%
fact_loans.to_sql(
    "fact_loans",
    engine,
    if_exists="replace",
    index=False
)
print("Loans table loaded successfuly")
# Out:
# Loans table loaded successfuly

# %%
dim_accounts.to_sql(
    "dim_accounts",
    engine,
    if_exists="replace",
    index=False
)
print("Accounts table loaded successfuly")
# Out:
# Accounts table loaded successfuly

# %%
transactions.head()
# Out:
#    transaction_id  account_id  customer_id transaction_type  \
# 0             1.0         205          247          Deposit
# 1             2.0         586          334              NaN
# 2             3.0         126          244          Deposit
# 3             NaN         234          119       Withdrawal
# 4             5.0         602          247         Transfer
#
#    transaction_amount transaction_channel transaction_status  \
# 0          2345874.74                 NaN             Failed
# 1          3214875.69                 NaN         Successful
# 2          2191351.07                 POS             Failed
# 3          4931673.79                 ATM                NaN
# 4          3161069.27                 NaN             Failed
#
#       transaction_date
# 0  2025-08-31 06:42:38
# 1  2025-07-09 22:42:08
# 2  2025-09-26 04:29:16
# 3  2024-09-09 19:26:32
# 4  2024-12-30 17:22:55

# %%
dim_accounts.describe()
# Out:
#        account_id  customer_id  opening_balance
# count   700.00000   700.000000       700.000000
# mean    350.50000   272.145714    500337.959714
# std     202.21688   156.000904    290559.018809
# min       1.00000     1.000000     -1876.630000
# 25%     175.75000   139.000000    248729.287500
# 50%     350.50000   270.000000    510588.185000
# 75%     525.25000   397.500000    756485.460000
# max     700.00000   548.000000    999959.940000
